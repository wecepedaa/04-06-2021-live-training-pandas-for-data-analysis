# %%
import pandas as pd

# %%
pd.read_csv("C:/Users/wecep/Objectel/ListTest.csv", index_col="Group Name",low_memory=False)
# Out:
#                 Tier  RecordID  ProviderEntityID  \
# Group Name
# Align Networks    -1     84142            125861
# Align Networks    -1    103764            129343
# Align Networks    -1    106784            136107
# Align Networks    -1    122878            167566
# Align Networks    -1    131499            184425
# ...              ...       ...               ...
# Align Networks    20     79405            178810
# Align Networks    20     79405            178810
# Align Networks    20     78870            181692
# Align Networks    21     20213             65334
# Align Networks    21     79405            149192
#
#                                                     Facility Name  \
# Group Name
# Align Networks       Jingyu Liu dba Acupuncture & Herbal Medicine
# Align Networks  Palm Imaging Institute A Medical Corporation D...
# Align Networks  Palm Imaging Institute A Medical Corporation D...
# Align Networks               Haeseong Integrative Medicine Center
# ...

# %%
pd.read_csv("C:/Users/wecep/Objectel/ListTest.csv", low_memory=False)
# Out:
#        Tier  RecordID  ProviderEntityID      Group Name  \
# 0        -1     84142            125861  Align Networks
# 1        -1    103764            129343  Align Networks
# 2        -1    106784            136107  Align Networks
# 3        -1    122878            167566  Align Networks
# 4        -1    131499            184425  Align Networks
# ...     ...       ...               ...             ...
# 25705    20     79405            178810  Align Networks
# 25706    20     79405            178810  Align Networks
# 25707    20     78870            181692  Align Networks
# 25708    21     20213             65334  Align Networks
# 25709    21     79405            149192  Align Networks
#
#                                            Facility Name  \
# 0           Jingyu Liu dba Acupuncture & Herbal Medicine
# 1      Palm Imaging Institute A Medical Corporation D...
# 2      Palm Imaging Institute A Medical Corporation D...
# 3                   Haeseong Integrative Medicine Center
# ...

# %%
align = pd.read_csv("C:/Users/wecep/Objectel/ListTest.csv", low_memory=False)

# %%
align = pd.read_csv("C:/Users/wecep/Objectel/ListTest.csv", squeeze=True,low_memory=False)

# %%
align.head(5)
# Out:
#    Tier  RecordID  ProviderEntityID      Group Name  \
# 0    -1     84142            125861  Align Networks
# 1    -1    103764            129343  Align Networks
# 2    -1    106784            136107  Align Networks
# 3    -1    122878            167566  Align Networks
# 4    -1    131499            184425  Align Networks
#
#                                        Facility Name  \
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine
# 1  Palm Imaging Institute A Medical Corporation D...
# 2  Palm Imaging Institute A Medical Corporation D...
# 3               Haeseong Integrative Medicine Center
# 4               William Speech Therapy Services, Inc
#
#                  ProviderEmail ProviderFirstName  ProviderMiddleName  \
# 0  Referrals@AlignNetworks.com            Jingyu                 NaN
# 1  Referrals@AlignNetworks.com               NaN                 NaN
# 2  Referrals@AlignNetworks.com             Steve                 NaN
# ...

# %%
align.tail()
# Out:
#        Tier  RecordID  ProviderEntityID      Group Name  \
# 25705    20     79405            178810  Align Networks
# 25706    20     79405            178810  Align Networks
# 25707    20     78870            181692  Align Networks
# 25708    21     20213             65334  Align Networks
# 25709    21     79405            149192  Align Networks
#
#                                            Facility Name  \
# 25705  Advanced Dynamics Physical Therapy DBA Matthew...
# 25706  Advanced Dynamics Physical Therapy DBA Matthew...
# 25707  Alejandro J. Katz, Licensed Acupuncturist, Pai...
# 25708   Andy Truongvinh dba Andy Truongvinh Chiropractic
# 25709  Advanced Dynamics Physical Therapy DBA Matthew...
#
#                      ProviderEmail ProviderFirstName  ProviderMiddleName  \
# 25705  Referrals@AlignNetworks.com             Mabel                 NaN
# 25706  Referrals@AlignNetworks.com           Matthew                 NaN
# ...

# %%
align.sort_values(by="Tier")
# Out:
#        Tier  RecordID  ProviderEntityID      Group Name  \
# 0        -1     84142            125861  Align Networks
# 1        -1    103764            129343  Align Networks
# 2        -1    106784            136107  Align Networks
# 3        -1    122878            167566  Align Networks
# 4        -1    131499            184425  Align Networks
# ...     ...       ...               ...             ...
# 25676    20    102231            126247  Align Networks
# 25677    20    102422            126560  Align Networks
# 25665    20     89929            114593  Align Networks
# 25708    21     20213             65334  Align Networks
# 25709    21     79405            149192  Align Networks
#
#                                            Facility Name  \
# 0           Jingyu Liu dba Acupuncture & Herbal Medicine
# 1      Palm Imaging Institute A Medical Corporation D...
# 2      Palm Imaging Institute A Medical Corporation D...
# 3                   Haeseong Integrative Medicine Center
# ...

# %%
align.sort_values(by="Tier",inplace = True)

# %%
align.head()
# Out:
#    Tier  RecordID  ProviderEntityID      Group Name  \
# 0    -1     84142            125861  Align Networks
# 1    -1    103764            129343  Align Networks
# 2    -1    106784            136107  Align Networks
# 3    -1    122878            167566  Align Networks
# 4    -1    131499            184425  Align Networks
#
#                                        Facility Name  \
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine
# 1  Palm Imaging Institute A Medical Corporation D...
# 2  Palm Imaging Institute A Medical Corporation D...
# 3               Haeseong Integrative Medicine Center
# 4               William Speech Therapy Services, Inc
#
#                  ProviderEmail ProviderFirstName  ProviderMiddleName  \
# 0  Referrals@AlignNetworks.com            Jingyu                 NaN
# 1  Referrals@AlignNetworks.com               NaN                 NaN
# 2  Referrals@AlignNetworks.com             Steve                 NaN
# ...

# %%
align.value_counts()
align.value_counts(ascending = False)
# Out:
# Series([], dtype: int64)

# %%
align.head()
# Out:
#    Tier  RecordID  ProviderEntityID      Group Name  \
# 0    -1     84142            125861  Align Networks
# 1    -1    103764            129343  Align Networks
# 2    -1    106784            136107  Align Networks
# 3    -1    122878            167566  Align Networks
# 4    -1    131499            184425  Align Networks
#
#                                        Facility Name  \
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine
# 1  Palm Imaging Institute A Medical Corporation D...
# 2  Palm Imaging Institute A Medical Corporation D...
# 3               Haeseong Integrative Medicine Center
# 4               William Speech Therapy Services, Inc
#
#                  ProviderEmail ProviderFirstName  ProviderMiddleName  \
# 0  Referrals@AlignNetworks.com            Jingyu                 NaN
# 1  Referrals@AlignNetworks.com               NaN                 NaN
# 2  Referrals@AlignNetworks.com             Steve                 NaN
# ...

# %%
align = pd.read_csv("C://Users/wecep/Objectel/ListTest.csv", squeeze=True,low_memory=False, index_col="Group Name")

# %%
align.value_counts()
align.value_counts(ascending = False)
# Out:
# Series([], dtype: int64)

# %%
align.value_counts("Group Name")
# Out:
# Group Name
# Align Networks    25710
# dtype: int64

# %%
align.value_counts("ProviderFirstName")
# Out:
# ProviderFirstName
# Michael        290
# Christopher    278
# Matthew        256
# Andrew         247
# Jennifer       237
#               ...
# KARLO            1
# Jyoti            1
# Jushua           1
# Juntae           1
# yanzhong         1
# Length: 2796, dtype: int64

# %%
align.value_counts("ProviderLastName")
# Out:
# ProviderLastName
# Lee           225
# Schwartz      151
# Chen          140
# King          134
# Amato         133
#              ...
# J MORTON        1
# J Mangan        1
# J McMillin      1
# J Medina        1
# zhu             1
# Length: 6245, dtype: int64

# %%
align.value_counts("Facility Tax ID")
# Out:
# Facility Tax ID
# 815145975.0    4482
# 825160608.0    2850
# 330912929.0    2521
# 330493339.0     850
# 912073074.0     775
#                ...
# 612372892.0       1
# 613054161.0       1
# 613650947.0       1
# 614205792.0       1
# 954888108.0       1
# Length: 1787, dtype: int64

# %%
align.value_counts("Provider Tax ID")
# Out:
# Provider Tax ID
# 270276119    25710
# dtype: int64

# %%
align.value_counts("PhysicalTherapistNPI")
# Out:
# PhysicalTherapistNPI
#               2937
# 1689215956     134
# 1659740942     134
# 1861554693     132
# 1124547260     131
#               ...
# 1548554397       1
# 1548574379       1
# 1548579154       1
# 1164624599       1
# 954814783        1
# Length: 5443, dtype: int64

# %%
align.value_counts("ServiceFacilityNPI")
# Out:
# ServiceFacilityNPI
# 1.952395e+09    1893
# 1.952395e+08     628
# 1.841268e+08     621
# 1.770830e+09     550
# 1.811911e+08     504
#                 ...
# 1.104816e+09       1
# 1.104377e+09       1
# 1.104291e+09       1
# 1.104131e+09       1
# 6.194603e+09       1
# Length: 1945, dtype: int64

# %%
align.columns
# Out:
# Index(['Tier', 'RecordID', 'ProviderEntityID', 'Facility Name',
#        'ProviderEmail', 'ProviderFirstName', 'ProviderMiddleName',
#        'ProviderLastName', 'Facility Tax ID', 'Provider Tax ID', 'Degree',
#        'License', 'PrimarySpecialty', 'PracticeStreet1', 'PracticeStreet2',
#        'PracticeCity', 'State', 'PracticeZip', 'FacilityPhone',
#        'PracticePhone', 'Fax', 'BillingAddress1', 'BillingAddress2',
#        'BillingCity', 'BillingState', 'BillingZip', 'BillingPhone',
#        'BillingFax', 'PLgroupNPI', 'SB863ConfirmationDate',
#        'PhysicalTherapistNPI', 'ServiceFacilityNPI', 'ReferralOnly',
#        'AcceptingWCPatients', 'RenderingProviderEmail'],
#       dtype='object')

# %%
align.value_counts("BillingState")
# Out:
# BillingState
# GA    25710
# dtype: int64

# %%
align.value_counts("State")
# Out:
# State
# CA    25710
# dtype: int64

# %%
align.value_counts("Facility Name")
# Out:
# Facility Name
# New Life Physical Therapy Services PC dba New Life Rehabilitation                                     4478
# CALIFORNIA LUNA CARE PHYSICAL THERAPY PC-Mobile PT                                                    2826
# MDRS Spine & Sport, Inc                                                                               2454
# San Luis Physical Therapy and Orthopedic Rehabilitation Inc dba Movement for Life Physical Therapy     574
# Vargo Physical Therapy, Inc                                                                            523
#                                                                                                       ...
# Ed Green dba Ed Green Chiropractic                                                                       1
# Eckerson Chiropractic                                                                                    1
# New Light Physical Therapy and Wellness Center                                                           1
# ...

# %%
align.value_counts("BillingZip")
# Out:
# BillingZip
# 30348-5159    25710
# dtype: int64

# %%
align.value_counts("PrimarySpecialty", ascending = True)
# Out:
# PrimarySpecialty
# Could be All                 5
# Massage Therapy             29
# Acupuncture                916
# Chiropractic Services      987
# Physical Therapy         23773
# dtype: int64

# %%
align.value_counts("State")
# Out:
# State
# CA    25710
# dtype: int64

# %%
align.value_counts("PrimarySpecialty",normalize = True) * 100
# Out:
# PrimarySpecialty
# Physical Therapy         92.465967
# Chiropractic Services     3.838973
# Acupuncture               3.562816
# Massage Therapy           0.112797
# Could be All              0.019448
# dtype: float64

# %%
align.nunique()
# Out:
# Tier                        13
# RecordID                  1768
# ProviderEntityID          3085
# Facility Name             1942
# ProviderEmail                1
# ProviderFirstName         2796
# ProviderMiddleName           0
# ProviderLastName          6245
# Facility Tax ID           1787
# Provider Tax ID              1
# Degree                       0
# License                   7129
# PrimarySpecialty             5
# PracticeStreet1           3042
# PracticeStreet2              0
# PracticeCity               657
# State                        1
# PracticeZip                829
# FacilityPhone             2450
# PracticePhone                1
# Fax                          1
# BillingAddress1              1
# BillingAddress2              0
# BillingCity                  1
# BillingState                 1
# BillingZip                   1
# BillingPhone                 1
# BillingFax                   1
# PLgroupNPI                1751
# SB863ConfirmationDate        1
# ...

# %%
align.nunique()
# Out:
# Tier                        13
# RecordID                  1768
# ProviderEntityID          3085
# Group Name                   1
# Facility Name             1942
# ProviderEmail                1
# ProviderFirstName         2796
# ProviderMiddleName           0
# ProviderLastName          6245
# Facility Tax ID           1787
# Provider Tax ID              1
# Degree                       0
# License                   7129
# PrimarySpecialty             5
# PracticeStreet1           3042
# PracticeStreet2              0
# PracticeCity               657
# State                        1
# PracticeZip                829
# FacilityPhone             2450
# PracticePhone                1
# Fax                          1
# BillingAddress1              1
# BillingAddress2              0
# BillingCity                  1
# BillingState                 1
# BillingZip                   1
# BillingPhone                 1
# BillingFax                   1
# PLgroupNPI                1751
# ...

# %%
align.drop_duplicates()
# Out:
#        Tier  RecordID  ProviderEntityID      Group Name  \
# 0        -1     84142            125861  Align Networks
# 1        -1    103764            129343  Align Networks
# 2        -1    106784            136107  Align Networks
# 3        -1    122878            167566  Align Networks
# 4        -1    131499            184425  Align Networks
# ...     ...       ...               ...             ...
# 25705    20     79405            178810  Align Networks
# 25706    20     79405            178810  Align Networks
# 25707    20     78870            181692  Align Networks
# 25708    21     20213             65334  Align Networks
# 25709    21     79405            149192  Align Networks
#
#                                            Facility Name  \
# 0           Jingyu Liu dba Acupuncture & Herbal Medicine
# 1      Palm Imaging Institute A Medical Corporation D...
# 2      Palm Imaging Institute A Medical Corporation D...
# 3                   Haeseong Integrative Medicine Center
# ...

# %%
align.head()
# Out:
#                 Tier  RecordID  ProviderEntityID  \
# Group Name
# Align Networks    -1     84142            125861
# Align Networks    -1    103764            129343
# Align Networks    -1    106784            136107
# Align Networks    -1    122878            167566
# Align Networks    -1    131499            184425
#
#                                                     Facility Name  \
# Group Name
# Align Networks       Jingyu Liu dba Acupuncture & Herbal Medicine
# Align Networks  Palm Imaging Institute A Medical Corporation D...
# Align Networks  Palm Imaging Institute A Medical Corporation D...
# Align Networks               Haeseong Integrative Medicine Center
# Align Networks               William Speech Therapy Services, Inc
#
#                               ProviderEmail ProviderFirstName  \
# Group Name
# Align Networks  Referrals@AlignNetworks.com            Jingyu
# Align Networks  Referrals@AlignNetworks.com               NaN
# ...

# %%
align.iloc[100]
# Out:
# Tier                                                        0
# RecordID                                                 1567
# ProviderEntityID                                        46698
# Facility Name                       Concentra Medical Centers
# ProviderEmail                     Referrals@AlignNetworks.com
# ProviderFirstName                                     Michael
# ProviderMiddleName                                        NaN
# ProviderLastName                                       Coller
# Facility Tax ID                                   770469725.0
# Provider Tax ID                                     270276119
# Degree                                                    NaN
# License                                               DC22410
# PrimarySpecialty                             Physical Therapy
# PracticeStreet1                          1675 Alhambra Blvd B
# PracticeStreet2                                           NaN
# ...

# %%
align.iloc[[0, 3, 5, 10]]
# Out:
#                 Tier  RecordID  ProviderEntityID  \
# Group Name
# Align Networks    -1     84142            125861
# Align Networks    -1    122878            167566
# Align Networks     0      1567              5282
# Align Networks     0      1567              5282
#
#                                                Facility Name  \
# Group Name
# Align Networks  Jingyu Liu dba Acupuncture & Herbal Medicine
# Align Networks          Haeseong Integrative Medicine Center
# Align Networks                     Concentra Medical Centers
# Align Networks                     Concentra Medical Centers
#
#                               ProviderEmail ProviderFirstName  \
# Group Name
# Align Networks  Referrals@AlignNetworks.com            Jingyu
# Align Networks  Referrals@AlignNetworks.com                On
# Align Networks  Referrals@AlignNetworks.com               NaN
# Align Networks  Referrals@AlignNetworks.com             Sapna
#
# ...

# %%
align.iloc[-3:]
# Out:
#                 Tier  RecordID  ProviderEntityID  \
# Group Name
# Align Networks    20     78870            181692
# Align Networks    21     20213             65334
# Align Networks    21     79405            149192
#
#                                                     Facility Name  \
# Group Name
# Align Networks  Alejandro J. Katz, Licensed Acupuncturist, Pai...
# Align Networks   Andy Truongvinh dba Andy Truongvinh Chiropractic
# Align Networks  Advanced Dynamics Physical Therapy DBA Matthew...
#
#                               ProviderEmail ProviderFirstName  \
# Group Name
# Align Networks  Referrals@AlignNetworks.com               NaN
# Align Networks  Referrals@AlignNetworks.com                DR
# Align Networks  Referrals@AlignNetworks.com           Matthew
#
#                 ProviderMiddleName ProviderLastName  Facility Tax ID  \
# Group Name
# Align Networks                 NaN              NaN      954456330.0
# ...

# %%
align.iloc[:3]
# Out:
#                 Tier  RecordID  ProviderEntityID  \
# Group Name
# Align Networks    -1     84142            125861
# Align Networks    -1    103764            129343
# Align Networks    -1    106784            136107
#
#                                                     Facility Name  \
# Group Name
# Align Networks       Jingyu Liu dba Acupuncture & Herbal Medicine
# Align Networks  Palm Imaging Institute A Medical Corporation D...
# Align Networks  Palm Imaging Institute A Medical Corporation D...
#
#                               ProviderEmail ProviderFirstName  \
# Group Name
# Align Networks  Referrals@AlignNetworks.com            Jingyu
# Align Networks  Referrals@AlignNetworks.com               NaN
# Align Networks  Referrals@AlignNetworks.com             Steve
#
#                 ProviderMiddleName ProviderLastName  Facility Tax ID  \
# Group Name
# Align Networks                 NaN              Liu      616861912.0
# ...

# %%
align.loc[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
align = pd.read_csv("C:/Users/wecep/Objectel/ListTest.csv",low_memory=False, parse_dates=["SB863ConfirmationDate"])

# %%
align.head(3)
# Out:
#    Tier  RecordID  ProviderEntityID      Group Name  \
# 0    -1     84142            125861  Align Networks
# 1    -1    103764            129343  Align Networks
# 2    -1    106784            136107  Align Networks
#
#                                        Facility Name  \
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine
# 1  Palm Imaging Institute A Medical Corporation D...
# 2  Palm Imaging Institute A Medical Corporation D...
#
#                  ProviderEmail ProviderFirstName  ProviderMiddleName  \
# 0  Referrals@AlignNetworks.com            Jingyu                 NaN
# 1  Referrals@AlignNetworks.com               NaN                 NaN
# 2  Referrals@AlignNetworks.com             Steve                 NaN
#
#   ProviderLastName  Facility Tax ID  ...  BillingZip  BillingPhone  \
# 0              Liu      616861912.0  ...  30348-5159    8663890211
# 1              NaN      330638761.0  ...  30348-5159    8663890211
# ...

# %%
align.shape
# Out:
# (25710, 36)

# %%
align.size
# Out:
# 925560

# %%
align.head(3)
# Out:
#    Tier  RecordID  ProviderEntityID      Group Name  \
# 0    -1     84142            125861  Align Networks
# 1    -1    103764            129343  Align Networks
# 2    -1    106784            136107  Align Networks
#
#                                        Facility Name  \
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine
# 1  Palm Imaging Institute A Medical Corporation D...
# 2  Palm Imaging Institute A Medical Corporation D...
#
#                  ProviderEmail ProviderFirstName  ProviderMiddleName  \
# 0  Referrals@AlignNetworks.com            Jingyu                 NaN
# 1  Referrals@AlignNetworks.com               NaN                 NaN
# 2  Referrals@AlignNetworks.com             Steve                 NaN
#
#   ProviderLastName  Facility Tax ID  ...  BillingZip  BillingPhone  \
# 0              Liu      616861912.0  ...  30348-5159    8663890211
# 1              NaN      330638761.0  ...  30348-5159    8663890211
# ...

# %%
align.dtypes
# Out:
# Tier                               int64
# RecordID                           int64
# ProviderEntityID                   int64
# Group Name                        object
# Facility Name                     object
# ProviderEmail                     object
# ProviderFirstName                 object
# ProviderMiddleName               float64
# ProviderLastName                  object
# Facility Tax ID                  float64
# Provider Tax ID                    int64
# Degree                           float64
# License                           object
# PrimarySpecialty                  object
# PracticeStreet1                   object
# PracticeStreet2                  float64
# PracticeCity                      object
# State                             object
# PracticeZip                        int64
# FacilityPhone                      int64
# PracticePhone                      int64
# Fax                                int64
# BillingAddress1                   object
# ...

# %%
align.nunique()
# Out:
# Tier                        13
# RecordID                  1768
# ProviderEntityID          3085
# Group Name                   1
# Facility Name             1942
# ProviderEmail                1
# ProviderFirstName         2796
# ProviderMiddleName           0
# ProviderLastName          6245
# Facility Tax ID           1787
# Provider Tax ID              1
# Degree                       0
# License                   7129
# PrimarySpecialty             5
# PracticeStreet1           3042
# PracticeStreet2              0
# PracticeCity               657
# State                        1
# PracticeZip                829
# FacilityPhone             2450
# PracticePhone                1
# Fax                          1
# BillingAddress1              1
# BillingAddress2              0
# BillingCity                  1
# BillingState                 1
# BillingZip                   1
# BillingPhone                 1
# BillingFax                   1
# PLgroupNPI                1751
# ...

# %%
align.sample(3)
# Out:
#        Tier  RecordID  ProviderEntityID      Group Name  \
# 16173     3    131429            185236  Align Networks
# 21037     4     11182            146641  Align Networks
# 12686     3     14570             64229  Align Networks
#
#                                            Facility Name  \
# 16173  CALIFORNIA LUNA CARE PHYSICAL THERAPY PC-Mobil...
# 21037                            MDRS Spine & Sport, Inc
# 12686                    West Star Physical Therapy, Inc
#
#                      ProviderEmail ProviderFirstName  ProviderMiddleName  \
# 16173  Referrals@AlignNetworks.com            Joshua                 NaN
# 21037  Referrals@AlignNetworks.com             Kevin                 NaN
# 12686  Referrals@AlignNetworks.com              John                 NaN
#
#       ProviderLastName  Facility Tax ID  ...  BillingZip  BillingPhone  \
# 16173         Schwartz      825160608.0  ...  30348-5159    8663890211
# ...

# %%
align.max()
# Out:
# C:\Users\wecep\AppData\Local\Temp/ipykernel_3364/1287763311.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   align.max()
# Tier                                              21
# RecordID                                      132271
# ProviderEntityID                              187716
# Group Name                            Align Networks
# Facility Name                          Zylna Granado
# ProviderEmail            Referrals@AlignNetworks.com
# ProviderMiddleName                               NaN
# Facility Tax ID                          954888108.0
# Provider Tax ID                            270276119
# Degree                                           NaN
# PrimarySpecialty                    Physical Therapy
# PracticeStreet1          Virtual Physical Therapists
# ...

# %%
align.min()
# Out:
# C:\Users\wecep\AppData\Local\Temp/ipykernel_3364/391082504.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   align.min()
# Tier                                              -1
# RecordID                                         424
# ProviderEntityID                                5282
# Group Name                            Align Networks
# Facility Name                   DR LAURA SCIURBA LAC
# ProviderEmail            Referrals@AlignNetworks.com
# ProviderMiddleName                               NaN
# Facility Tax ID                            2680188.0
# Provider Tax ID                            270276119
# Degree                                           NaN
# PrimarySpecialty                         Acupuncture
# PracticeStreet1                 1 CIVIC CENTER PLAZA
# ...

# %%
align.PrimarySpecialty
# Out:
# 0                  Acupuncture
# 1             Physical Therapy
# 2             Physical Therapy
# 3             Physical Therapy
# 4             Physical Therapy
#                  ...
# 25705         Physical Therapy
# 25706         Physical Therapy
# 25707              Acupuncture
# 25708    Chiropractic Services
# 25709         Physical Therapy
# Name: PrimarySpecialty, Length: 25710, dtype: object

# %%
align["PrimarySpecialty"].head().sort_values()
# Out:
# 0         Acupuncture
# 1    Physical Therapy
# 2    Physical Therapy
# 3    Physical Therapy
# 4    Physical Therapy
# Name: PrimarySpecialty, dtype: object

# %%
align["PrimarySpecialty"].tail().sort_values()
# Out:
# 25707              Acupuncture
# 25708    Chiropractic Services
# 25705         Physical Therapy
# 25706         Physical Therapy
# 25709         Physical Therapy
# Name: PrimarySpecialty, dtype: object

# %%
align["PrimarySpecialty"].sort_values().tail()
# Out:
# 8605     Physical Therapy
# 8604     Physical Therapy
# 8603     Physical Therapy
# 8613     Physical Therapy
# 25709    Physical Therapy
# Name: PrimarySpecialty, dtype: object

# %%
align["PrimarySpecialty"].sort_values().head()
# Out:
# 0        Acupuncture
# 24261    Acupuncture
# 24262    Acupuncture
# 24263    Acupuncture
# 24264    Acupuncture
# Name: PrimarySpecialty, dtype: object

# %%
align[["PrimarySpecialty","Facility Name","PracticeCity"]]
# Out:
#             PrimarySpecialty  \
# 0                Acupuncture
# 1           Physical Therapy
# 2           Physical Therapy
# 3           Physical Therapy
# 4           Physical Therapy
# ...                      ...
# 25705       Physical Therapy
# 25706       Physical Therapy
# 25707            Acupuncture
# 25708  Chiropractic Services
# 25709       Physical Therapy
#
#                                            Facility Name    PracticeCity
# 0           Jingyu Liu dba Acupuncture & Herbal Medicine         ANTIOCH
# 1      Palm Imaging Institute A Medical Corporation D...  SAN BERNARDINO
# 2      Palm Imaging Institute A Medical Corporation D...          COLTON
# 3                   Haeseong Integrative Medicine Center     LOS ANGELES
# 4                   William Speech Therapy Services, Inc          ENCINO
# ...                                                  ...             ...
# 25705  Advanced Dynamics Physical Therapy DBA Matthew...          DOWNEY
# ...

# %%
align[["PrimarySpecialty","Facility Name","PracticeCity"]].sort_values(by="PracticeCity").head(10)
# Out:
#             PrimarySpecialty  \
# 23828            Acupuncture
# 23829            Acupuncture
# 12300       Physical Therapy
# 12299       Physical Therapy
# 14077       Physical Therapy
# 25425  Chiropractic Services
# 25424  Chiropractic Services
# 25426  Chiropractic Services
# 3800        Physical Therapy
# 15925       Physical Therapy
#
#                                            Facility Name  PracticeCity
# 23828  Acton Acupuncture & Alternative Healing Center...         ACTON
# 23829  Acton Acupuncture & Alternative Healing Center...         ACTON
# 12300                     Santiago Physical Therapy, Inc         ACTON
# 12299                     Santiago Physical Therapy, Inc         ACTON
# 14077                         Santiyago Physical Therapy         ACTON
# 25425                         Agoura Family Chiropractic  AGOURA HILLS
# 25424                         Agoura Family Chiropractic  AGOURA HILLS
# ...

# %%
align[["PrimarySpecialty","Facility Name","PracticeCity"]].sort_values(by="PrimarySpecialty").head(10)
# Out:
#       PrimarySpecialty                                      Facility Name  \
# 0          Acupuncture       Jingyu Liu dba Acupuncture & Herbal Medicine
# 24261      Acupuncture  Charles Thomas Savoca dba Charles Savoca, Lice...
# 24262      Acupuncture                                   HealthMerica Inc
# 24263      Acupuncture  Celina Chua dba K.L. Family Acupuncture & Herb...
# 24264      Acupuncture      Shiva Rouhani dba Acupuncture Wellness Center
# 24265      Acupuncture   BonWellness Clinic, Inc dba Bon Wellness Clinic
# 24266      Acupuncture   BonWellness Clinic, Inc dba Bon Wellness Clinic
# 24267      Acupuncture              Jun Mi Yi DBA Barnabas Healing Center
# 24268      Acupuncture                                K&Y Acupuncture Inc
# 24269      Acupuncture               Jeungmo Kim DBA Bethesda Acupuncture
#
#       PracticeCity
# 0          ANTIOCH
# 24261     MONTEREY
# 24262    FULLERTON
# 24263       UPLAND
# 24264  WEST COVINA
# 24265   BUENA PARK
# ...

# %%
align.sort_values(by="PracticeCity")
# Out:
#        Tier  RecordID  ProviderEntityID      Group Name  \
# 23828     7     85031            106999  Align Networks
# 23829     7     85031            106999  Align Networks
# 12300     3     13291             46652  Align Networks
# 12299     3     13291             46652  Align Networks
# 14077     3    101744            176096  Align Networks
# ...     ...       ...               ...             ...
# 18383     4     10799             45859  Align Networks
# 18394     4     10799             45859  Align Networks
# 18377     4     10799             45859  Align Networks
# 24764     8     67807             72322  Align Networks
# 11521     3    118508             45171  Align Networks
#
#                                            Facility Name  \
# 23828  Acton Acupuncture & Alternative Healing Center...
# 23829  Acton Acupuncture & Alternative Healing Center...
# 12300                     Santiago Physical Therapy, Inc
# 12299                     Santiago Physical Therapy, Inc
# ...

# %%
align[["ProviderEntityID","PrimarySpecialty","Facility Name","PracticeCity"]].sort_values(by="ProviderEntityID", ascending = True)
# Out:
#        ProviderEntityID  PrimarySpecialty              Facility Name  \
# 5                  5282  Physical Therapy  Concentra Medical Centers
# 6                  5282  Physical Therapy  Concentra Medical Centers
# 7                  5282  Physical Therapy  Concentra Medical Centers
# 8                  5282  Physical Therapy  Concentra Medical Centers
# 9                  5282  Physical Therapy  Concentra Medical Centers
# ...                 ...               ...                        ...
# 23684            187712  Physical Therapy      Rise Physical Therapy
# 23685            187713  Physical Therapy      Rise Physical Therapy
# 23686            187714  Physical Therapy      Rise Physical Therapy
# 23687            187715  Physical Therapy      Rise Physical Therapy
# 23688            187716  Physical Therapy      Rise Physical Therapy
#
#            PracticeCity
# 5           Santa Clara
# 6           Santa Clara
# 7           Santa Clara
# 8           Santa Clara
# ...

# %%
align[["ProviderEntityID","PrimarySpecialty","Facility Name","PracticeCity"]].sort_values(by=["ProviderEntityID","PrimarySpecialty"], ascending = True)
# Out:
#        ProviderEntityID  PrimarySpecialty              Facility Name  \
# 5                  5282  Physical Therapy  Concentra Medical Centers
# 6                  5282  Physical Therapy  Concentra Medical Centers
# 7                  5282  Physical Therapy  Concentra Medical Centers
# 8                  5282  Physical Therapy  Concentra Medical Centers
# 9                  5282  Physical Therapy  Concentra Medical Centers
# ...                 ...               ...                        ...
# 23684            187712  Physical Therapy      Rise Physical Therapy
# 23685            187713  Physical Therapy      Rise Physical Therapy
# 23686            187714  Physical Therapy      Rise Physical Therapy
# 23687            187715  Physical Therapy      Rise Physical Therapy
# 23688            187716  Physical Therapy      Rise Physical Therapy
#
#            PracticeCity
# 5           Santa Clara
# 6           Santa Clara
# 7           Santa Clara
# 8           Santa Clara
# ...

# %%
align[["ProviderEntityID","PrimarySpecialty","Facility Name","PracticeCity"]].sort_values(by=["PrimarySpecialty","ProviderEntityID"], ascending = True)
# Out:
#        ProviderEntityID  PrimarySpecialty  \
# 23689             59840       Acupuncture
# 23690             59840       Acupuncture
# 23691             71656       Acupuncture
# 23692             71656       Acupuncture
# 23693             74463       Acupuncture
# ...                 ...               ...
# 23684            187712  Physical Therapy
# 23685            187713  Physical Therapy
# 23686            187714  Physical Therapy
# 23687            187715  Physical Therapy
# 23688            187716  Physical Therapy
#
#                                        Facility Name      PracticeCity
# 23689               Robin Farkas Hays, L.Ac., DNBAO           MILPITAS
# 23690               Robin Farkas Hays, L.Ac., DNBAO           MILPITAS
# 23691                         GQC Acupuncture Clinic      SHERMAN OAKS
# 23692                         GQC Acupuncture Clinic      SHERMAN OAKS
# 23693  Chinese Medicine & Acupuncture Institute, INC       WESTMINSTER
# ...

# %%
align.sort_values(by=["PrimarySpecialty","ProviderEntityID","PracticeCity"], ascending = True).head()
# Out:
#        Tier  RecordID  ProviderEntityID      Group Name  \
# 23689     7     17490             59840  Align Networks
# 23690     7     17490             59840  Align Networks
# 23691     7     57242             71656  Align Networks
# 23692     7     57242             71656  Align Networks
# 23693     7     54073             74463  Align Networks
#
#                                        Facility Name  \
# 23689               Robin Farkas Hays, L.Ac., DNBAO
# 23690               Robin Farkas Hays, L.Ac., DNBAO
# 23691                         GQC Acupuncture Clinic
# 23692                         GQC Acupuncture Clinic
# 23693  Chinese Medicine & Acupuncture Institute, INC
#
#                      ProviderEmail ProviderFirstName  ProviderMiddleName  \
# 23689  Referrals@AlignNetworks.com             Robin                 NaN
# 23690  Referrals@AlignNetworks.com             Robin                 NaN
# 23691  Referrals@AlignNetworks.com               NaN                 NaN
# ...

# %%
align.sort_index(inplace = True)
align.head()
# Out:
#    Tier  RecordID  ProviderEntityID      Group Name  \
# 0    -1     84142            125861  Align Networks
# 1    -1    103764            129343  Align Networks
# 2    -1    106784            136107  Align Networks
# 3    -1    122878            167566  Align Networks
# 4    -1    131499            184425  Align Networks
#
#                                        Facility Name  \
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine
# 1  Palm Imaging Institute A Medical Corporation D...
# 2  Palm Imaging Institute A Medical Corporation D...
# 3               Haeseong Integrative Medicine Center
# 4               William Speech Therapy Services, Inc
#
#                  ProviderEmail ProviderFirstName  ProviderMiddleName  \
# 0  Referrals@AlignNetworks.com            Jingyu                 NaN
# 1  Referrals@AlignNetworks.com               NaN                 NaN
# 2  Referrals@AlignNetworks.com             Steve                 NaN
# ...

# %%
align.sort_index(axis = 1)
align.sort_index(axis = "columns", inplace = True)

# %%
align.head()
# Out:
#   AcceptingWCPatients  BillingAddress1  BillingAddress2 BillingCity  \
# 0                   Y  P.O. Box 105159              NaN     Atlanta
# 1                   Y  P.O. Box 105159              NaN     Atlanta
# 2                   Y  P.O. Box 105159              NaN     Atlanta
# 3                   Y  P.O. Box 105159              NaN     Atlanta
# 4                   Y  P.O. Box 105159              NaN     Atlanta
#
#    BillingFax  BillingPhone BillingState  BillingZip  Degree  \
# 0  9049980299    8663890211           GA  30348-5159     NaN
# 1  9049980299    8663890211           GA  30348-5159     NaN
# 2  9049980299    8663890211           GA  30348-5159     NaN
# 3  9049980299    8663890211           GA  30348-5159     NaN
# 4  9049980299    8663890211           GA  30348-5159     NaN
#
#                                        Facility Name  ...  ProviderFirstName  \
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine  ...             Jingyu
# ...

# %%
align.iloc[350]
# Out:
# AcceptingWCPatients                                                       Y
# BillingAddress1                                             P.O. Box 105159
# BillingAddress2                                                         NaN
# BillingCity                                                         Atlanta
# BillingFax                                                       9049980299
# BillingPhone                                                     8663890211
# BillingState                                                             GA
# BillingZip                                                       30348-5159
# Degree                                                                  NaN
# Facility Name             Matrix Rehabilitation  Inc. dba Select Physica...
# Facility Tax ID                                                 710783147.0
# FacilityPhone                                                    8317248235
# ...

# %%
align[["ProviderEntityID","PrimarySpecialty","Facility Name","PracticeCity"]].iloc[[350, 355,1000]]
# Out:
#       ProviderEntityID  PrimarySpecialty  \
# 350              45778  Physical Therapy
# 355              45782  Physical Therapy
# 1000             55993  Physical Therapy
#
#                                           Facility Name PracticeCity
# 350   Matrix Rehabilitation  Inc. dba Select Physica...  WATSONVILLE
# 355           May Mardini dba Recovery Physical Therapy     STOCKTON
# 1000                            MDRS Spine & Sport, Inc  CHULA VISTA

# %%
align[["ProviderEntityID","PrimarySpecialty","Facility Name","PracticeCity"]].iloc[350:355]
# Out:
#      ProviderEntityID  PrimarySpecialty  \
# 350             45778  Physical Therapy
# 351             45782  Physical Therapy
# 352             45782  Physical Therapy
# 353             45782  Physical Therapy
# 354             45782  Physical Therapy
#
#                                          Facility Name PracticeCity
# 350  Matrix Rehabilitation  Inc. dba Select Physica...  WATSONVILLE
# 351          May Mardini dba Recovery Physical Therapy     STOCKTON
# 352          May Mardini dba Recovery Physical Therapy     STOCKTON
# 353          May Mardini dba Recovery Physical Therapy     STOCKTON
# 354          May Mardini dba Recovery Physical Therapy     STOCKTON

# %%
align.sort_index(inplace = True)

# %%
align[["ProviderEntityID","PrimarySpecialty","Facility Name","PracticeCity"]].head()
# Out:
#    ProviderEntityID  PrimarySpecialty  \
# 0            125861       Acupuncture
# 1            129343  Physical Therapy
# 2            136107  Physical Therapy
# 3            167566  Physical Therapy
# 4            184425  Physical Therapy
#
#                                        Facility Name    PracticeCity
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine         ANTIOCH
# 1  Palm Imaging Institute A Medical Corporation D...  SAN BERNARDINO
# 2  Palm Imaging Institute A Medical Corporation D...          COLTON
# 3               Haeseong Integrative Medicine Center     LOS ANGELES
# 4               William Speech Therapy Services, Inc          ENCINO

# %%
align.head()
# Out:
#    level_0  index AcceptingWCPatients  BillingAddress1  BillingAddress2  \
# 0        0      0                   Y  P.O. Box 105159              NaN
# 1        1      1                   Y  P.O. Box 105159              NaN
# 2        2      2                   Y  P.O. Box 105159              NaN
# 3        3      3                   Y  P.O. Box 105159              NaN
# 4        4      4                   Y  P.O. Box 105159              NaN
#
#   BillingCity  BillingFax  BillingPhone BillingState  BillingZip  ...  \
# 0     Atlanta  9049980299    8663890211           GA  30348-5159  ...
# 1     Atlanta  9049980299    8663890211           GA  30348-5159  ...
# 2     Atlanta  9049980299    8663890211           GA  30348-5159  ...
# 3     Atlanta  9049980299    8663890211           GA  30348-5159  ...
# 4     Atlanta  9049980299    8663890211           GA  30348-5159  ...
#
#    ProviderFirstName ProviderLastName  ProviderMiddleName  RecordID  \
# ...

# %%
newAlign=align[["ProviderEntityID","PrimarySpecialty","Facility Name","PracticeCity"]]

# %%
newAlign.head()
# Out:
#    ProviderEntityID  PrimarySpecialty  \
# 0            125861       Acupuncture
# 1            129343  Physical Therapy
# 2            136107  Physical Therapy
# 3            167566  Physical Therapy
# 4            184425  Physical Therapy
#
#                                        Facility Name    PracticeCity
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine         ANTIOCH
# 1  Palm Imaging Institute A Medical Corporation D...  SAN BERNARDINO
# 2  Palm Imaging Institute A Medical Corporation D...          COLTON
# 3               Haeseong Integrative Medicine Center     LOS ANGELES
# 4               William Speech Therapy Services, Inc          ENCINO

# %%
newAlign.sort_index()
# Out:
#        ProviderEntityID       PrimarySpecialty  \
# 0                125861            Acupuncture
# 1                129343       Physical Therapy
# 2                136107       Physical Therapy
# 3                167566       Physical Therapy
# 4                184425       Physical Therapy
# ...                 ...                    ...
# 25705            178810       Physical Therapy
# 25706            178810       Physical Therapy
# 25707            181692            Acupuncture
# 25708             65334  Chiropractic Services
# 25709            149192       Physical Therapy
#
#                                            Facility Name    PracticeCity
# 0           Jingyu Liu dba Acupuncture & Herbal Medicine         ANTIOCH
# 1      Palm Imaging Institute A Medical Corporation D...  SAN BERNARDINO
# 2      Palm Imaging Institute A Medical Corporation D...          COLTON
# 3                   Haeseong Integrative Medicine Center     LOS ANGELES
# ...

# %%
newAlign.sort_index(axis =0).head()
# Out:
#    ProviderEntityID  PrimarySpecialty  \
# 0            125861       Acupuncture
# 1            129343  Physical Therapy
# 2            136107  Physical Therapy
# 3            167566  Physical Therapy
# 4            184425  Physical Therapy
#
#                                        Facility Name    PracticeCity
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine         ANTIOCH
# 1  Palm Imaging Institute A Medical Corporation D...  SAN BERNARDINO
# 2  Palm Imaging Institute A Medical Corporation D...          COLTON
# 3               Haeseong Integrative Medicine Center     LOS ANGELES
# 4               William Speech Therapy Services, Inc          ENCINO

# %%
newAlign.sort_index(axis =1).head()
# Out:
#                                        Facility Name    PracticeCity  \
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine         ANTIOCH
# 1  Palm Imaging Institute A Medical Corporation D...  SAN BERNARDINO
# 2  Palm Imaging Institute A Medical Corporation D...          COLTON
# 3               Haeseong Integrative Medicine Center     LOS ANGELES
# 4               William Speech Therapy Services, Inc          ENCINO
#
#    PrimarySpecialty  ProviderEntityID
# 0       Acupuncture            125861
# 1  Physical Therapy            129343
# 2  Physical Therapy            136107
# 3  Physical Therapy            167566
# 4  Physical Therapy            184425

# %%
newAlign.sort_index(axis ="columns", inplace = True)

# %%
newAlign.head()
# Out:
#                                        Facility Name    PracticeCity  \
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine         ANTIOCH
# 1  Palm Imaging Institute A Medical Corporation D...  SAN BERNARDINO
# 2  Palm Imaging Institute A Medical Corporation D...          COLTON
# 3               Haeseong Integrative Medicine Center     LOS ANGELES
# 4               William Speech Therapy Services, Inc          ENCINO
#
#    PrimarySpecialty  ProviderEntityID
# 0       Acupuncture            125861
# 1  Physical Therapy            129343
# 2  Physical Therapy            136107
# 3  Physical Therapy            167566
# 4  Physical Therapy            184425

# %%
newAlign.loc(1)

# %%
newAlign.head()
# Out:
#                                        Facility Name    PracticeCity  \
# 0       Jingyu Liu dba Acupuncture & Herbal Medicine         ANTIOCH
# 1  Palm Imaging Institute A Medical Corporation D...  SAN BERNARDINO
# 2  Palm Imaging Institute A Medical Corporation D...          COLTON
# 3               Haeseong Integrative Medicine Center     LOS ANGELES
# 4               William Speech Therapy Services, Inc          ENCINO
#
#    PrimarySpecialty  ProviderEntityID
# 0       Acupuncture            125861
# 1  Physical Therapy            129343
# 2  Physical Therapy            136107
# 3  Physical Therapy            167566
# 4  Physical Therapy            184425

# %%
newAlign.iloc[350]
# Out:
# Facility Name       Matrix Rehabilitation  Inc. dba Select Physica...
# PracticeCity                                              WATSONVILLE
# PrimarySpecialty                                     Physical Therapy
# ProviderEntityID                                                45778
# Name: 350, dtype: object

# %%
newAlign.iloc[-35:-33]
# Out:
#                   Facility Name  PracticeCity PrimarySpecialty  \
# 25675  Advanced Acupuncture Inc  SANTA MONICA      Acupuncture
# 25676  Advanced Acupuncture Inc  SANTA MONICA      Acupuncture
#
#        ProviderEntityID
# 25675            126247
# 25676            126247

# %%
newAlign.reset_index(inplace = True)

# %%
newAlign.head()
# Out:
#    index                                      Facility Name    PracticeCity  \
# 0      0       Jingyu Liu dba Acupuncture & Herbal Medicine         ANTIOCH
# 1      1  Palm Imaging Institute A Medical Corporation D...  SAN BERNARDINO
# 2      2  Palm Imaging Institute A Medical Corporation D...          COLTON
# 3      3               Haeseong Integrative Medicine Center     LOS ANGELES
# 4      4               William Speech Therapy Services, Inc          ENCINO
#
#    PrimarySpecialty  ProviderEntityID
# 0       Acupuncture            125861
# 1  Physical Therapy            129343
# 2  Physical Therapy            136107
# 3  Physical Therapy            167566
# 4  Physical Therapy            184425

# %%
newAlign.tail()
# Out:
#        index                                      Facility Name  PracticeCity  \
# 25705  25705  Advanced Dynamics Physical Therapy DBA Matthew...        DOWNEY
# 25706  25706  Advanced Dynamics Physical Therapy DBA Matthew...        DOWNEY
# 25707  25707  Alejandro J. Katz, Licensed Acupuncturist, Pai...       BURBANK
# 25708  25708   Andy Truongvinh dba Andy Truongvinh Chiropractic  REDWOOD CITY
# 25709  25709  Advanced Dynamics Physical Therapy DBA Matthew...        DOWNEY
#
#             PrimarySpecialty  ProviderEntityID
# 25705       Physical Therapy            178810
# 25706       Physical Therapy            178810
# 25707            Acupuncture            181692
# 25708  Chiropractic Services             65334
# 25709       Physical Therapy            149192

# %%
newAlign.loc["index","PracticeCity"]="DOWNEY"
# Out:
# C:\Users\wecep\AppData\Local\Temp/ipykernel_3364/1479290052.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newAlign.loc["index","PracticeCity"]="DOWNEY"

# %%
newAlign["PracticeCity"]=="DOWNEY"
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 25706    True
# 25707    True
# 25708    True
# 25709    True
# index    True
# Name: PracticeCity, Length: 25711, dtype: bool

# %%
newAlign["PracticeCity"]=="LOS ANGELES"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25706    False
# 25707    False
# 25708    False
# 25709    False
# index    False
# Name: PracticeCity, Length: 25711, dtype: bool

# %%
is_Downey = newAlign["PracticeCity"]=="DOWNEY"

# %%
is_losAngeles
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 25706    True
# 25707    True
# 25708    True
# 25709    True
# index    True
# Name: PracticeCity, Length: 25711, dtype: bool

# %%
newAlign[is_Downey].head()
# Out:
#    index                                      Facility Name PracticeCity  \
# 0    0.0       Jingyu Liu dba Acupuncture & Herbal Medicine       DOWNEY
# 1    1.0  Palm Imaging Institute A Medical Corporation D...       DOWNEY
# 2    2.0  Palm Imaging Institute A Medical Corporation D...       DOWNEY
# 3    3.0               Haeseong Integrative Medicine Center       DOWNEY
# 4    4.0               William Speech Therapy Services, Inc       DOWNEY
#
#    PrimarySpecialty  ProviderEntityID (0, PracticeCity)
# 0       Acupuncture          125861.0            DOWNEY
# 1  Physical Therapy          129343.0            DOWNEY
# 2  Physical Therapy          136107.0            DOWNEY
# 3  Physical Therapy          167566.0            DOWNEY
# 4  Physical Therapy          184425.0            DOWNEY

# %%
acu = newAlign["PrimarySpecialty"]=="Acupuncture"
newAlign[acu].head()
# Out:
#        index                                      Facility Name PracticeCity  \
# 0        0.0       Jingyu Liu dba Acupuncture & Herbal Medicine       DOWNEY
# 2891  2891.0           Won Hee Cho DBA True Healing Acupuncture       DOWNEY
# 3150  3150.0  United University of Los Angeles, Inc. DBA Uni...       DOWNEY
# 3151  3151.0  United University of Los Angeles, Inc. DBA Uni...       DOWNEY
# 3152  3152.0  United University of Los Angeles, Inc. DBA Uni...       DOWNEY
#
#      PrimarySpecialty  ProviderEntityID (0, PracticeCity)
# 0         Acupuncture          125861.0            DOWNEY
# 2891      Acupuncture          170446.0            DOWNEY
# 3150      Acupuncture          113636.0            DOWNEY
# 3151      Acupuncture          113636.0            DOWNEY
# 3152      Acupuncture          113636.0            DOWNEY

# %%
ent = newAlign["ProviderEntityID"]> 185000
newAlign[ent].head()
# Out:
#        index              Facility Name PracticeCity  PrimarySpecialty  \
# 189    189.0  Concentra Medical Centers       DOWNEY  Physical Therapy
# 190    190.0  Concentra Medical Centers       DOWNEY  Physical Therapy
# 4738  4738.0  Concentra Medical Centers       DOWNEY  Physical Therapy
# 4739  4739.0  Concentra Medical Centers       DOWNEY  Physical Therapy
# 4740  4740.0  Concentra Medical Centers       DOWNEY  Physical Therapy
#
#       ProviderEntityID (0, PracticeCity)
# 189           185906.0            DOWNEY
# 190           185908.0            DOWNEY
# 4738          185614.0            DOWNEY
# 4739          185614.0            DOWNEY
# 4740          185614.0            DOWNEY

# %%
newAlign[acu & ent]
# Out:
#          index                                      Facility Name  \
# 4796    4796.0          Jin Wook Choi dba MAUM ACUPUNCTURE CLINIC
# 24594  24594.0           Jin Kyou Lim DBA Lims Acupuncture Clinic
# 24595  24595.0  Alejandro J. Katz, Licensed Acupuncturist, Pai...
# 24596  24596.0   Bradley Cimino LACdba Pro Active Acupuncture Inc
# 24597  24597.0  Alejandro J. Katz, Licensed Acupuncturist, Pai...
# 24598  24598.0  Alejandro J. Katz, Licensed Acupuncturist, Pai...
# 24599  24599.0            Karen Ann Fisher DBA Alpine Acupuncture
# 24600  24600.0                         KSJ Acupuncture Clinic Inc
# 24601  24601.0  Alejandro J. Katz, Licensed Acupuncturist, Pai...
# 24602  24602.0  Alejandro J. Katz, Licensed Acupuncturist, Pai...
# 24603  24603.0  Alejandro J. Katz, Licensed Acupuncturist, Pai...
# 24604  24604.0  Alejandro J. Katz, Licensed Acupuncturist, Pai...
# 24605  24605.0  Alejandro J. Katz, Licensed Acupuncturist, Pai...
# ...

# %%
newAlign[acu | ent]
# Out:
#          index                                      Facility Name  \
# 0          0.0       Jingyu Liu dba Acupuncture & Herbal Medicine
# 189      189.0                          Concentra Medical Centers
# 190      190.0                          Concentra Medical Centers
# 2891    2891.0           Won Hee Cho DBA True Healing Acupuncture
# 3150    3150.0  United University of Los Angeles, Inc. DBA Uni...
# ...        ...                                                ...
# 25665  25665.0       Chau AI Au dba Aus Acupuncture & Herb Clinic
# 25675  25675.0                           Advanced Acupuncture Inc
# 25676  25676.0                           Advanced Acupuncture Inc
# 25677  25677.0  United Alternative Medical Group Inc dba T.Y. ...
# 25707  25707.0  Alejandro J. Katz, Licensed Acupuncturist, Pai...
#
#       PracticeCity  PrimarySpecialty  ProviderEntityID (0, PracticeCity)
# 0           DOWNEY       Acupuncture          125861.0            DOWNEY
# ...

# %%
newAlign[~acu]
# Out:
#          index                                      Facility Name  \
# 1          1.0  Palm Imaging Institute A Medical Corporation D...
# 2          2.0  Palm Imaging Institute A Medical Corporation D...
# 3          3.0               Haeseong Integrative Medicine Center
# 4          4.0               William Speech Therapy Services, Inc
# 5          5.0                          Concentra Medical Centers
# ...        ...                                                ...
# 25705  25705.0  Advanced Dynamics Physical Therapy DBA Matthew...
# 25706  25706.0  Advanced Dynamics Physical Therapy DBA Matthew...
# 25708  25708.0   Andy Truongvinh dba Andy Truongvinh Chiropractic
# 25709  25709.0  Advanced Dynamics Physical Therapy DBA Matthew...
# index      NaN                                                NaN
#
#       PracticeCity       PrimarySpecialty  ProviderEntityID (0, PracticeCity)
# 1           DOWNEY       Physical Therapy          129343.0            DOWNEY
# ...

# %%
newAlign[newAlign["ProviderEntityID"].between(5000, 6000)].head()
# Out:
#    index              Facility Name PracticeCity  PrimarySpecialty  \
# 5    5.0  Concentra Medical Centers       DOWNEY  Physical Therapy
# 6    6.0  Concentra Medical Centers       DOWNEY  Physical Therapy
# 7    7.0  Concentra Medical Centers       DOWNEY  Physical Therapy
# 8    8.0  Concentra Medical Centers       DOWNEY  Physical Therapy
# 9    9.0  Concentra Medical Centers       DOWNEY  Physical Therapy
#
#    ProviderEntityID (0, PracticeCity)
# 5            5282.0            DOWNEY
# 6            5282.0            DOWNEY
# 7            5282.0            DOWNEY
# 8            5282.0            DOWNEY
# 9            5282.0            DOWNEY

# %%
Align = pd.read_csv("C:/Users/wecep/Objectel/ListTest.csv", index_col="Group Name",low_memory=False)

# %%
Align.head()
# Out:
#                 Tier  RecordID  ProviderEntityID  \
# Group Name
# Align Networks    -1     84142            125861
# Align Networks    -1    103764            129343
# Align Networks    -1    106784            136107
# Align Networks    -1    122878            167566
# Align Networks    -1    131499            184425
#
#                                                     Facility Name  \
# Group Name
# Align Networks       Jingyu Liu dba Acupuncture & Herbal Medicine
# Align Networks  Palm Imaging Institute A Medical Corporation D...
# Align Networks  Palm Imaging Institute A Medical Corporation D...
# Align Networks               Haeseong Integrative Medicine Center
# Align Networks               William Speech Therapy Services, Inc
#
#                               ProviderEmail ProviderFirstName  \
# Group Name
# Align Networks  Referrals@AlignNetworks.com            Jingyu
# Align Networks  Referrals@AlignNetworks.com               NaN
# ...

# %%
newA = align[["ProviderEntityID","PrimarySpecialty","Facility Name","PracticeCity"]]

# %%
newA
# Out:
#        ProviderEntityID       PrimarySpecialty  \
# 0                125861            Acupuncture
# 1                129343       Physical Therapy
# 2                136107       Physical Therapy
# 3                167566       Physical Therapy
# 4                184425       Physical Therapy
# ...                 ...                    ...
# 25705            178810       Physical Therapy
# 25706            178810       Physical Therapy
# 25707            181692            Acupuncture
# 25708             65334  Chiropractic Services
# 25709            149192       Physical Therapy
#
#                                            Facility Name    PracticeCity
# 0           Jingyu Liu dba Acupuncture & Herbal Medicine         ANTIOCH
# 1      Palm Imaging Institute A Medical Corporation D...  SAN BERNARDINO
# 2      Palm Imaging Institute A Medical Corporation D...          COLTON
# 3                   Haeseong Integrative Medicine Center     LOS ANGELES
# ...

# %%
newA["PrimarySpecialty"].head()
# Out:
# 0         Acupuncture
# 1    Physical Therapy
# 2    Physical Therapy
# 3    Physical Therapy
# 4    Physical Therapy
# Name: PrimarySpecialty, dtype: object

# %%
newA["PrimarySpecialty"].head().values
# Out:
# array(['Acupuncture', 'Physical Therapy', 'Physical Therapy',
#        'Physical Therapy', 'Physical Therapy'], dtype=object)

# %%
newA["PrimarySpecialty"].str

# %%
newA["PrimarySpecialty"].str.lstrip().head()
# Out:
# 0         Acupuncture
# 1    Physical Therapy
# 2    Physical Therapy
# 3    Physical Therapy
# 4    Physical Therapy
# Name: PrimarySpecialty, dtype: object

# %%
newA["PrimarySpecialty"].str.rstrip().head()
# Out:
# 0         Acupuncture
# 1    Physical Therapy
# 2    Physical Therapy
# 3    Physical Therapy
# 4    Physical Therapy
# Name: PrimarySpecialty, dtype: object

# %%
newA["PrimarySpecialty"].str.strip().head()
# Out:
# 0         Acupuncture
# 1    Physical Therapy
# 2    Physical Therapy
# 3    Physical Therapy
# 4    Physical Therapy
# Name: PrimarySpecialty, dtype: object

# %%
newA.columns
# Out:
# Index(['ProviderEntityID', 'PrimarySpecialty', 'Facility Name',
#        'PracticeCity'],
#       dtype='object')

# %%
for column in newA.columns:
    print(column)
    if column.isnumeric == False:
        newA[column] = newA[column].str.strip()
# Out:
# ProviderEntityID
# PrimarySpecialty
# Facility Name
# PracticeCity

# %%
len(newA)
# Out:
# 25710

# %%
newA["PrimarySpecialty"].unique()
# Out:
# array(['Acupuncture', 'Physical Therapy', 'Chiropractic Services',
#        'Massage Therapy', 'Could be All'], dtype=object)

# %%
newA["PrimarySpecialty"].str.lower().str.contains("all").head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: PrimarySpecialty, dtype: bool

# %%
hasAll = newA["PrimarySpecialty"].str.lower().str.contains("all")
newA[hasAll]
# Out:
#        ProviderEntityID PrimarySpecialty              Facility Name  \
# 25646             46677     Could be All  Concentra Medical Centers
# 25647             46677     Could be All  Concentra Medical Centers
# 25648             46677     Could be All  Concentra Medical Centers
# 25649             46677     Could be All  Concentra Medical Centers
# 25650            144616     Could be All  Concentra Medical Centers
#
#       PracticeCity
# 25646    RIVERSIDE
# 25647    RIVERSIDE
# 25648    RIVERSIDE
# 25649    RIVERSIDE
# 25650   SACRAMENTO

# %%
newA[hasAll].head()
# Out:
#        ProviderEntityID PrimarySpecialty              Facility Name  \
# 25646             46677     Could be All  Concentra Medical Centers
# 25647             46677     Could be All  Concentra Medical Centers
# 25648             46677     Could be All  Concentra Medical Centers
# 25649             46677     Could be All  Concentra Medical Centers
# 25650            144616     Could be All  Concentra Medical Centers
#
#       PracticeCity
# 25646    RIVERSIDE
# 25647    RIVERSIDE
# 25648    RIVERSIDE
# 25649    RIVERSIDE
# 25650   SACRAMENTO

# %%
startP = newA["PrimarySpecialty"].str.lower().str.startswith("co")
newA[startP]
# Out:
#        ProviderEntityID PrimarySpecialty              Facility Name  \
# 25646             46677     Could be All  Concentra Medical Centers
# 25647             46677     Could be All  Concentra Medical Centers
# 25648             46677     Could be All  Concentra Medical Centers
# 25649             46677     Could be All  Concentra Medical Centers
# 25650            144616     Could be All  Concentra Medical Centers
#
#       PracticeCity
# 25646    RIVERSIDE
# 25647    RIVERSIDE
# 25648    RIVERSIDE
# 25649    RIVERSIDE
# 25650   SACRAMENTO

# %%
endP = newA["PrimarySpecialty"].str.lower().str.endswith("ll")
newA[endP]
# Out:
#        ProviderEntityID PrimarySpecialty              Facility Name  \
# 25646             46677     Could be All  Concentra Medical Centers
# 25647             46677     Could be All  Concentra Medical Centers
# 25648             46677     Could be All  Concentra Medical Centers
# 25649             46677     Could be All  Concentra Medical Centers
# 25650            144616     Could be All  Concentra Medical Centers
#
#       PracticeCity
# 25646    RIVERSIDE
# 25647    RIVERSIDE
# 25648    RIVERSIDE
# 25649    RIVERSIDE
# 25650   SACRAMENTO

# %%
Align = pd.read_csv("C:/Users/wecep/Objectel/ListTest.csv", index_col="Group Name",low_memory=False)

# %%
Align.columns
# Out:
# Index(['Tier', 'RecordID', 'ProviderEntityID', 'Facility Name',
#        'ProviderEmail', 'ProviderFirstName', 'ProviderMiddleName',
#        'ProviderLastName', 'Facility Tax ID', 'Provider Tax ID', 'Degree',
#        'License', 'PrimarySpecialty', 'PracticeStreet1', 'PracticeStreet2',
#        'PracticeCity', 'State', 'PracticeZip', 'FacilityPhone',
#        'PracticePhone', 'Fax', 'BillingAddress1', 'BillingAddress2',
#        'BillingCity', 'BillingState', 'BillingZip', 'BillingPhone',
#        'BillingFax', 'PLgroupNPI', 'SB863ConfirmationDate',
#        'PhysicalTherapistNPI', 'ServiceFacilityNPI', 'ReferralOnly',
#        'AcceptingWCPatients', 'RenderingProviderEmail'],
#       dtype='object')

# %%
provider = Align[["ProviderFirstName", "ProviderMiddleName","ProviderLastName","ProviderEntityID","PrimarySpecialty","Facility Name","PracticeCity"]]

# %%
provider.head()
# Out:
#                ProviderFirstName  ProviderMiddleName ProviderLastName  \
# Group Name
# Align Networks            Jingyu                 NaN              Liu
# Align Networks               NaN                 NaN              NaN
# Align Networks             Steve                 NaN           Zecker
# Align Networks                On                 NaN        Jung Park
# Align Networks               NaN                 NaN              NaN
#
#                 ProviderEntityID  PrimarySpecialty  \
# Group Name
# Align Networks            125861       Acupuncture
# Align Networks            129343  Physical Therapy
# Align Networks            136107  Physical Therapy
# Align Networks            167566  Physical Therapy
# Align Networks            184425  Physical Therapy
#
#                                                     Facility Name  \
# Group Name
# Align Networks       Jingyu Liu dba Acupuncture & Herbal Medicine
# ...

# %%
provider["ProviderFirstName"].str.len().head()
# Out:
# Group Name
# Align Networks    6.0
# Align Networks    NaN
# Align Networks    5.0
# Align Networks    2.0
# Align Networks    NaN
# Name: ProviderFirstName, dtype: float64

# %%
provider["Facility Name"].str.split(" ").head()
# Out:
# Group Name
# Align Networks    [Jingyu, Liu, dba, Acupuncture, &, Herbal, Med...
# Align Networks    [Palm, Imaging, Institute, A, Medical, Corpora...
# Align Networks    [Palm, Imaging, Institute, A, Medical, Corpora...
# Align Networks            [Haeseong, Integrative, Medicine, Center]
# Align Networks           [William, Speech, Therapy, Services,, Inc]
# Name: Facility Name, dtype: object

# %%
provider["PrimarySpecialty"].str.split(" ").head()
# Out:
# Group Name
# Align Networks          [Acupuncture]
# Align Networks    [Physical, Therapy]
# Align Networks    [Physical, Therapy]
# Align Networks    [Physical, Therapy]
# Align Networks    [Physical, Therapy]
# Name: PrimarySpecialty, dtype: object

# %%
phone_number = '"555"|"-123"|"4567"'
phone_number.split('"|"')
# Out:
# ['"555', '-123', '4567"']

# %%
phone_number[0]
# Out:
# '"'

# %%
provider["Facility Name"].str.split(" ", n=1).head()
# Out:
# Group Name
# Align Networks      [Jingyu, Liu dba Acupuncture & Herbal Medicine]
# Align Networks    [Palm, Imaging Institute A Medical Corporation...
# Align Networks    [Palm, Imaging Institute A Medical Corporation...
# Align Networks              [Haeseong, Integrative Medicine Center]
# Align Networks              [William, Speech Therapy Services, Inc]
# Name: Facility Name, dtype: object

# %%
provider["Facility Name"].str.split(" ", n=1).str.get(0).head()
# Out:
# Group Name
# Align Networks      Jingyu
# Align Networks        Palm
# Align Networks        Palm
# Align Networks    Haeseong
# Align Networks     William
# Name: Facility Name, dtype: object

# %%
provider["Facility Name"].str.split(pat = " ", n=1, expand = True).head()
# Out:
#                        0                                                  1
# Group Name
# Align Networks    Jingyu              Liu dba Acupuncture & Herbal Medicine
# Align Networks      Palm  Imaging Institute A Medical Corporation DBA-Em...
# Align Networks      Palm  Imaging Institute A Medical Corporation DBA-Em...
# Align Networks  Haeseong                        Integrative Medicine Center
# Align Networks   William                       Speech Therapy Services, Inc

# %%
provider[["FirstName", "LastName"]]= provider["Facility Name"].str.split(pat = " ", n=1, expand = True)
# Out:
# C:\Users\wecep\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
provider
# Out:
#                ProviderFirstName  ProviderMiddleName ProviderLastName  \
# Group Name
# Align Networks            Jingyu                 NaN              Liu
# Align Networks               NaN                 NaN              NaN
# Align Networks             Steve                 NaN           Zecker
# Align Networks                On                 NaN        Jung Park
# Align Networks               NaN                 NaN              NaN
# ...                          ...                 ...              ...
# Align Networks             Mabel                 NaN            Cobos
# Align Networks           Matthew                 NaN            Perry
# Align Networks               NaN                 NaN              NaN
# Align Networks                DR                 NaN  ANDY TRUONGVINH
# Align Networks           Matthew                 NaN         R. Perry
#
#                 ProviderEntityID       PrimarySpecialty  \
# Group Name
# ...

# %%
Spec = Align[["ProviderFirstName", "ProviderMiddleName","ProviderLastName","ProviderEntityID","PrimarySpecialty","Facility Name","PracticeCity"]]

# %%
Spec.head()
# Out:
#                ProviderFirstName  ProviderMiddleName ProviderLastName  \
# Group Name
# Align Networks            Jingyu                 NaN              Liu
# Align Networks               NaN                 NaN              NaN
# Align Networks             Steve                 NaN           Zecker
# Align Networks                On                 NaN        Jung Park
# Align Networks               NaN                 NaN              NaN
#
#                 ProviderEntityID  PrimarySpecialty  \
# Group Name
# Align Networks            125861       Acupuncture
# Align Networks            129343  Physical Therapy
# Align Networks            136107  Physical Therapy
# Align Networks            167566  Physical Therapy
# Align Networks            184425  Physical Therapy
#
#                                                     Facility Name  \
# Group Name
# Align Networks       Jingyu Liu dba Acupuncture & Herbal Medicine
# ...

# %%
Spec.pivot_table(index="PrimarySpecialty")
# Out:
#                        ProviderEntityID
# PrimarySpecialty
# Acupuncture               142422.599345
# Chiropractic Services      98170.491388
# Could be All               66264.800000
# Massage Therapy           171801.965517
# Physical Therapy          130405.011399

# %%
Spec.pivot_table(index = "PrimarySpecialty", aggfunc = "mean")
# Out:
#                        ProviderEntityID
# PrimarySpecialty
# Acupuncture               142422.599345
# Chiropractic Services      98170.491388
# Could be All               66264.800000
# Massage Therapy           171801.965517
# Physical Therapy          130405.011399

# %%
Spec.pivot_table(index = "PrimarySpecialty", aggfunc = "count")
# Out:
#                        Facility Name  PracticeCity  ProviderEntityID  \
# PrimarySpecialty
# Acupuncture                      916           916               916
# Chiropractic Services            987           987               987
# Could be All                       5             5                 5
# Massage Therapy                   29            29                29
# Physical Therapy               23773         23773             23773
#
#                        ProviderFirstName  ProviderLastName  ProviderMiddleName
# PrimarySpecialty
# Acupuncture                          854               856                   0
# Chiropractic Services                986               987                   0
# Could be All                           4                 4                   0
# Massage Therapy                       29                29                   0
# Physical Therapy                   23009             23052                   0

# %%
Spec.pivot_table(index = "PrimarySpecialty", aggfunc = "sum")
# Out:
#                        ProviderEntityID  ProviderMiddleName
# PrimarySpecialty
# Acupuncture                   130459101                 0.0
# Chiropractic Services          96894275                 0.0
# Could be All                     331324                 0.0
# Massage Therapy                 4982257                 0.0
# Physical Therapy             3100118336                 0.0

# %%
Spec.pivot_table(index = "PrimarySpecialty", aggfunc = "sum", values="ProviderEntityID")
# Out:
#                        ProviderEntityID
# PrimarySpecialty
# Acupuncture                   130459101
# Chiropractic Services          96894275
# Could be All                     331324
# Massage Therapy                 4982257
# Physical Therapy             3100118336

# %%
Spec.pivot_table(index = "PrimarySpecialty", columns= "PracticeCity", aggfunc = "sum", values="ProviderEntityID")
# Out:
# PracticeCity              ACTON  AGOURA HILLS    ALAMEDA   ALHAMBRA  \
# PrimarySpecialty
# Acupuncture            213998.0           NaN        NaN   164005.0
# Chiropractic Services       NaN      406854.0   118445.0   977332.0
# Could be All                NaN           NaN        NaN        NaN
# Massage Therapy             NaN           NaN        NaN        NaN
# Physical Therapy       269400.0      155285.0  4260083.0  2487947.0
#
# PracticeCity           ALISO VIEJO    ALPINE     ANAHEIM  ANDERSON  \
# PrimarySpecialty
# Acupuncture                    NaN  186616.0   2495819.0       NaN
# Chiropractic Services          NaN       NaN   1017319.0       NaN
# Could be All                   NaN       NaN         NaN       NaN
# Massage Therapy                NaN       NaN         NaN       NaN
# Physical Therapy         2434877.0       NaN  17243666.0  268484.0
#
# PracticeCity           ANGELS CAMP    ANTIOCH  ...  West Sacramento  \
# ...

# %%
Spec.pivot_table(index = "PrimarySpecialty", columns= "PracticeCity", aggfunc = "count", values="ProviderEntityID")
# Out:
# PracticeCity           ACTON  AGOURA HILLS  ALAMEDA  ALHAMBRA  ALISO VIEJO  \
# PrimarySpecialty
# Acupuncture              2.0           NaN      NaN       1.0          NaN
# Chiropractic Services    NaN           3.0      1.0       8.0          NaN
# Could be All             NaN           NaN      NaN       NaN          NaN
# Massage Therapy          NaN           NaN      NaN       NaN          NaN
# Physical Therapy         3.0           1.0     23.0      19.0         24.0
#
# PracticeCity           ALPINE  ANAHEIM  ANDERSON  ANGELS CAMP  ANTIOCH  ...  \
# PrimarySpecialty                                                        ...
# Acupuncture               1.0     15.0       NaN          NaN      3.0  ...
# Chiropractic Services     NaN     10.0       NaN          NaN      NaN  ...
# Could be All              NaN      NaN       NaN          NaN      NaN  ...
# Massage Therapy           NaN      NaN       NaN          NaN      NaN  ...
# ...

# %%
Spec.pivot_table(
    index = "PrimarySpecialty", columns= "PracticeCity", aggfunc = "count", values="ProviderEntityID", 
    fill_value=0, margins=True)
# Out:
# PracticeCity           ACTON  AGOURA HILLS  ALAMEDA  ALHAMBRA  ALISO VIEJO  \
# PrimarySpecialty
# Acupuncture                2             0        0         1            0
# Chiropractic Services      0             3        1         8            0
# Could be All               0             0        0         0            0
# Massage Therapy            0             0        0         0            0
# Physical Therapy           3             1       23        19           24
# All                        5             4       24        28           24
#
# PracticeCity           ALPINE  ANAHEIM  ANDERSON  ANGELS CAMP  ANTIOCH  ...  \
# PrimarySpecialty                                                        ...
# Acupuncture                 1       15         0            0        3  ...
# Chiropractic Services       0       10         0            0        0  ...
# Could be All                0        0         0            0        0  ...
# ...

# %%
data = pd.read_csv("C:/Users/wecep/Objectel/ListTest.csv", index_col="Group Name",low_memory=False)

# %%
data.head()
# Out:
#                 Tier  RecordID  ProviderEntityID  \
# Group Name
# Align Networks    -1     84142            125861
# Align Networks    -1    103764            129343
# Align Networks    -1    106784            136107
# Align Networks    -1    122878            167566
# Align Networks    -1    131499            184425
#
#                                                     Facility Name  \
# Group Name
# Align Networks       Jingyu Liu dba Acupuncture & Herbal Medicine
# Align Networks  Palm Imaging Institute A Medical Corporation D...
# Align Networks  Palm Imaging Institute A Medical Corporation D...
# Align Networks               Haeseong Integrative Medicine Center
# Align Networks               William Speech Therapy Services, Inc
#
#                               ProviderEmail ProviderFirstName  \
# Group Name
# Align Networks  Referrals@AlignNetworks.com            Jingyu
# Align Networks  Referrals@AlignNetworks.com               NaN
# ...

# %%
# %%writefile test.txt
# Hello, this is a quick test file.
# Out:
# Writing test.txt

# %%
myfile = open('nba.csv')

# %%
pwd
# Out:
# 'C:\\Users\\wecep\\iCloudDrive\\UDEMY\\04-06-2021-live-training-pandas-for-data-analysis'

# %%
# We can now read the file
myfile.read()
# Out:
# "Name,Team,Position,Birthday,Salary\nShake Milton,Philadelphia 76ers,SG,9/26/96,1445697\nChristian Wood,Detroit Pistons,PF,9/27/95,1645357\nPJ Washington,Charlotte Hornets,PF,8/23/98,3831840\nDerrick Rose,Detroit Pistons,PG,10/4/88,7317074\nMarial Shayok,Philadelphia 76ers,G,7/26/95,79568\nDraymond Green,Golden State Warriors,PF,3/4/90,18539130\nKendrick Nunn,Miami Heat,SG,8/3/95,1416852\nCedi Osman,Cleveland Cavaliers,SF,4/8/95,2907143\nBrook Lopez,Milwaukee Bucks,C,4/1/88,12093024\nTorrey Craig,Denver Nuggets,SF,12/19/90,2000000\nJordan Clarkson,Cleveland Cavaliers,PG,6/7/92,13437500\nAlex Caruso,Los Angeles Lakers,PG,2/28/94,2750000\nNorvel Pelle,Philadelphia 76ers,FC,2/3/93,79568\nTyler Johnson,Phoenix Suns,PG,5/7/92,19245370\nAlec Burks,Golden State Warriors,SG,7/20/91,2320044\nJaMychal Green,Los Angeles Clippers,PF,6/21/90,4767000\nDwight Howard,Los Angeles Lakers,C,12/8/85,5603850\nNikola Jokic,Denver Nuggets,C,2/19/95,27504630\nChris Boucher,Toronto Raptors,PF,1/11/93,1588231
# ...

# %%
# Seek to the start of file (index 0)
myfile.seek(0)
# Out:
# 0

# %%
# Now read again
myfile.read()
# Out:
# "Name,Team,Position,Birthday,Salary\nShake Milton,Philadelphia 76ers,SG,9/26/96,1445697\nChristian Wood,Detroit Pistons,PF,9/27/95,1645357\nPJ Washington,Charlotte Hornets,PF,8/23/98,3831840\nDerrick Rose,Detroit Pistons,PG,10/4/88,7317074\nMarial Shayok,Philadelphia 76ers,G,7/26/95,79568\nDraymond Green,Golden State Warriors,PF,3/4/90,18539130\nKendrick Nunn,Miami Heat,SG,8/3/95,1416852\nCedi Osman,Cleveland Cavaliers,SF,4/8/95,2907143\nBrook Lopez,Milwaukee Bucks,C,4/1/88,12093024\nTorrey Craig,Denver Nuggets,SF,12/19/90,2000000\nJordan Clarkson,Cleveland Cavaliers,PG,6/7/92,13437500\nAlex Caruso,Los Angeles Lakers,PG,2/28/94,2750000\nNorvel Pelle,Philadelphia 76ers,FC,2/3/93,79568\nTyler Johnson,Phoenix Suns,PG,5/7/92,19245370\nAlec Burks,Golden State Warriors,SG,7/20/91,2320044\nJaMychal Green,Los Angeles Clippers,PF,6/21/90,4767000\nDwight Howard,Los Angeles Lakers,C,12/8/85,5603850\nNikola Jokic,Denver Nuggets,C,2/19/95,27504630\nChris Boucher,Toronto Raptors,PF,1/11/93,1588231
# ...

# %%
myfile.close()

# %%
data = pd.read_csv('nba.csv')

# %%
data.head()
# Out:
#              Name                Team Position Birthday   Salary
# 0    Shake Milton  Philadelphia 76ers       SG  9/26/96  1445697
# 1  Christian Wood     Detroit Pistons       PF  9/27/95  1645357
# 2   PJ Washington   Charlotte Hornets       PF  8/23/98  3831840
# 3    Derrick Rose     Detroit Pistons       PG  10/4/88  7317074
# 4   Marial Shayok  Philadelphia 76ers        G  7/26/95    79568

# %%
for line in open('nba.csv'):
    print(line)
# Out:
# Name,Team,Position,Birthday,Salary
#
# Shake Milton,Philadelphia 76ers,SG,9/26/96,1445697
#
# Christian Wood,Detroit Pistons,PF,9/27/95,1645357
#
# PJ Washington,Charlotte Hornets,PF,8/23/98,3831840
#
# Derrick Rose,Detroit Pistons,PG,10/4/88,7317074
#
# Marial Shayok,Philadelphia 76ers,G,7/26/95,79568
#
# Draymond Green,Golden State Warriors,PF,3/4/90,18539130
#
# Kendrick Nunn,Miami Heat,SG,8/3/95,1416852
#
# Cedi Osman,Cleveland Cavaliers,SF,4/8/95,2907143
#
# Brook Lopez,Milwaukee Bucks,C,4/1/88,12093024
#
# Torrey Craig,Denver Nuggets,SF,12/19/90,2000000
#
# Jordan Clarkson,Cleveland Cavaliers,PG,6/7/92,13437500
#
# Alex Caruso,Los Angeles Lakers,PG,2/28/94,2750000
#
# Norvel Pelle,Philadelphia 76ers,FC,2/3/93,79568
#
# Tyler Johnson,Phoenix Suns,PG,5/7/92,19245370
#
# Alec Burks,Golden State Warriors,SG,7/20/91,2320044
#
# JaMychal Green,Los Angeles Clippers,PF,6/21/90,4767000
#
# Dwight Howard,Los Angeles Lakers,C,12/8/85,5603850
#
# ...
